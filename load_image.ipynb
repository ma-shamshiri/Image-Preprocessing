# %%
from skimage import data
from skimage import io
import numpy as np 
import matplotlib.pyplot as plt

# %%
image = data.binary_blobs()

# %%
plt.imshow(image, cmap = "gray")

# %%
image = data.astronaut()

# %%
plt.imshow(image)

# %%
image = io.imread("C:/Users/HOME/Pictures/Saved Pictures/2.jpg")

# %%
plt.imshow(image)

# %%
images = io.ImageCollection("C:/Users/HOME/Pictures/Saved Pictures/*.png:C:/Users/HOME/Pictures/Saved Pictures/*.jpg")

# %%
plt.imshow(images)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e5448218d378> in <module>
# ----> 1 plt.imshow(images)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
# ...
