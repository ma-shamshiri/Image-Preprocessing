# %% [markdown]
# <a href="https://colab.research.google.com/github/ma-shamshiri/Image-Preprocessing/blob/master/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# this is the first program

# %%
import matplotlib.pyplot as plt
from skimage import data

# %%
image = data.astronaut()
plt.imshow(image)
